# %% [markdown]
# ### Library Import

# %%
import requests as req

# %%
from bs4 import BeautifulSoup as bs

# %%
# 요청을 할 때, 지연시간을 주기 위한 library
import time

# %% [markdown]
# ### Request/Response를 받아와야겠죠?

# %%
url = 'https://oneroommaking.com/product/detail.html?product_no=1911&cate_no=61&display_group=1'
res = req.get(url)
res
# Out:
# <Response [403]>

# %%
header = {'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36'}
res = req.get(url, headers = header)
res
# Out:
# <Response [200]>

# %% [markdown]
# ### BeautifulSoup 객체화 변경

# %%
soup = bs(res.text, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="ko" xml:lang="ko" xmlns="//www.w3.org/1999/xhtml"><head><script>(function(i, s, o, g, r, w) {
#     var a = s.createElement(o);
#     var m = s.getElementsByTagName(o)[0];
#     a.src = g;
#     a.onload = function() {
#         i[r].HOST = 'https://js-error-tracer-api.cafe24.com';
#         i[r].TOKEN = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..vyhyDHHdEAf2FgvfOd-xHcNOTbZYNMih6tn1sAGUQYM';
# ...

# %% [markdown]
# ### Select 함수를 써봅시다.

# %%
# 5개의 리뷰를 가져와야한다.
# select_one이 아닌 select를 사용해야한다.
review = soup.select('div.review_list_v2__expand_link.js-renewal-review-message-link.js-renewal-link-expand.disabled')
review
# Out:
# []

# %% [markdown]
# ### iframe이란
# - iframe tag = 기존 페이지 내에 새로운 페이지를 삽입하는 태그
# - 하나의 페이지 안에, 다른 페이지를 불러오는 것
# - 알부 쇼핑몰 웹사이트에서는 리뷰나 상품정보를 iframe으로 구성하여 보여주는 경우가 있음

# %%
url_iframe = 'https://review7.cre.ma/oneroommaking.com/products/reviews?product_code=1911&iframe_id=crema-product-reviews-2&widget_style=&app=0&parent_url=https%3A%2F%2Foneroommaking.com%2Fproduct%2Fdetail.html%3Fproduct_no%3D1911%26cate_no%3D61%26display_group%3D1&nonmember_token=&secure_device_token=V2f13f062feb4ad8d2fe649f11c672538ec4916f8e02e8056fa52b2022d65cdde30425215b58de40275153f840fb201f12&iframe=1'
header = {'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36'}
res_oneroom = req.get(url_iframe, headers = header)

# %%
res_oneroom
# Out:
# <Response [200]>

# %%
soup_review = bs(res_oneroom.text, 'lxml')
soup_review
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width,initial-scale=1.0,maximum-scale=1.0,minimum-scale=1.0,user-scalable=no" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>상세페이지 최하단 - 상품 리뷰</title>
# <link href="https://assets7.cre.ma/latte/assets/pc/application-578223ee960686070b8a2ae8cb3a6426fd06c633a3975c04405ae1f25304bbfe.css" media="all" rel="stylesheet"/>
# <link href="https://assets.cre.ma/m/favicons/crema/v3/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <style type="text/css">
#
#
# body #content {
#   background: transparent;
# }
#
# span.star, span.camera, .sprite_comment {
#   background-image: url(//assets7.cre.ma/p/oneroommaking-com/brand_settings/00/00/00/00/01/sprite/8b3d6b1018b952bf.png);
# }
#
# i.star {
#   color: #1f3fbf;
# }
#
# i.unstar:before {
#   color: #1f3fbf;
# }
#
#   i.star:before {
# ...

# %%
review_data = soup_review.select('div.review_list_v2__message.js-collapsed-review-content.js-translate-text')
review_data[0].text
# Out:
# '\n                    책뿐만 아니라 다양한 물품 두기에 좋네요 인테리에도 좋습니다\n                  '

# %% [markdown]
# ### for loop을 사용해서
# 1. 데이터를 추출
# 2. 텍스트만 동시 추출 및 공백을 동시에 제거

# %%
# cnt = 1
# cnt = 1로 초기화를 해주는데, 1부터 카운트가 되도록 세팅
# review_data의 길이만큼 범위를 주고 순차적으로 돌겠습니다.
for i in range(len(review_data)):
    # 리뷰 보기가 불편하니, 숫자로 출력을 구분지어 주겠습니다.
    # formatting을 사용해보도록 할게요.
#     print(f'[{cnt}]')
    print([i + 1])
#     cnt += 1
    # 아까 데이터를 보니 불필요한 공백이 너무 많았다.
    # 텍스트 데이터를 뽑으면서,
    # 동시에 strip()함수를 활용해서 문장 양엎의 공백을 제거
    print(review_data[i].text.strip())
    
    # 보기 좋게, 그리고 매우 간단하게 개행해주기
# Out:
# [1]
# 책뿐만 아니라 다양한 물품 두기에 좋네요 인테리에도 좋습니다
# [2]
# 조립하는데 대략 30분걸렸네요! 생각보다 작은 감이 없지 않아 있네요! 그래도 만족합니다
# [3]
# 손가락을 잃고 책장을 얻었다…. 뿌듯 근데 제품이 조금 까져서 왔더라구요… 괜춘괜춘합니다 ㅠㅡㅠ  하나 더 부를 거 같은데 이번에만 안까져서 오길 ㅎ ㅡㅎ
# [4]
# 조립 무조건 둘이서 하세요 혼자 하니까 두 시간 걸렸어요.. 못할 수준은 아닌데 둘이서 하면 30분정도면 끝냈을 듯..ㅠㅠ
# [5]
# 깔끔하고 죠습니다컬렉션 올려놓기 딱 좋네요

# %% [markdown]
# ### 1 - 5 페이지의 review 데이터를 수집

# %%
# 셀레니움 자동 브라우저가 아닌, beautifulsoup으로 진행
# key point - url의 로직

# %%
# 첫번째 페이지의 경우
    # 제품리뷰를 보여주는 위젯을 처음 로드

# 두번째 페이지의 경우
    # 로딩된 위젯 내에서 페이징(페이지를 왔다갔다하는 것)
    # 다음페이지의 리뷰를 로딩

# %%
# https://review7.cre.ma/oneroommaking.com/products/reviews?app=0&iframe=1&iframe_id=crema-product-reviews-2&parent_url=https%3A%2F%2Foneroommaking.com%2Fproduct%2Fdetail.html%3Fproduct_no%3D1911%26cate_no%3D61%26display_group%3D1&product_code=1911&secure_device_token

# %%
# https://review7.cre.ma/oneroommaking.com/products/reviews?app=0&iframe=1&iframe_id=crema-product-reviews-2&page=2&parent_url=https%3A%2F%2Foneroommaking.com%2Fproduct%2Fdetail.html%3Fproduct_no%3D1911%26cate_no%3D61%26display_group%3D1&product_code=1911&secure_device_token=V2c26c49798b678b5367dde9393aefc632a7ec4b849d05080fd331cef21fd252c8bfaf2e281921deb066e40748c3824d48&widget_env=100&widget_style=

# %%
# https://review7.cre.ma/oneroommaking.com/products/reviews?app=0&iframe=1&iframe_id=crema-product-reviews-2&page=3&parent_url=https%3A%2F%2Foneroommaking.com%2Fproduct%2Fdetail.html%3Fproduct_no%3D1911%26cate_no%3D61%26display_group%3D1&product_code=1911&secure_device_token=V2c26c49798b678b5367dde9393aefc632a7ec4b849d05080fd331cef21fd252c8bfaf2e281921deb066e40748c3824d48&widget_env=100&widget_style=

# %% [markdown]
# ### for loop을 사용해서 1부터 5페이지의 리뷰를 가져오기

# %%
for pageNo in range(1, 6):
#     1부터 5페이지를 반복하면서, pageNo변수에 반복횟수 할당
    url = 'https://review7.cre.ma/oneroommaking.com/products/reviews?app=0&iframe=1&iframe_id=crema-product-reviews-2&page={pageNo}&parent_url=https%3A%2F%2Foneroommaking.com%2Fproduct%2Fdetail.html%3Fproduct_no%3D1911%26cate_no%3D61%26display_group%3D1&product_code=1911&secure_device_token=V27d77736bba0d085af7bda96c4e75a52ec84fca4805f4948009515c2e5239e0bdab719cfcafcafcdfba4ec5230ea290bf&widget_env=100&widget_style='
    
    # url에 get 요청을 보내기 
    res = req.get(url, headers=header)
#     큵어오는 현재 페이지의 번호를 format함수로 기재/출력
    print(f'[현재 페이지 번호 :{pageNo}]')
#     BeautifulSoup 객체화
    soup = bs(res.text, 'lxml')
#     select함수를 사용해서, 리뷰들을 추출
    review_data = soup.select('div.review_list_v2__message.js-collapsed-review-content.js-translate-text')
    print(review_data[pageNo].text)
# Out:
# [현재 페이지 번호 :1]
#
#                     조립하는데 대략 30분걸렸네요! 생각보다 작은 감이 없지 않아 있네요! 그래도 만족합니다
#
# [현재 페이지 번호 :2]
#
#                     손가락을 잃고 책장을 얻었다…. 뿌듯 근데 제품이 조금 까져서 왔더라구요… 괜춘괜춘합니다 ㅠㅡㅠ  하나 더 부를 거 같은데 이번에만 안까져서 오길 ㅎ ㅡㅎ
#
# [현재 페이지 번호 :3]
#
#                     조립 무조건 둘이서 하세요 혼자 하니까 두 시간 걸렸어요.. 못할 수준은 아닌데 둘이서 하면 30분정도면 끝냈을 듯..ㅠㅠ
#
# [현재 페이지 번호 :4]
#
#                     깔끔하고 죠습니다컬렉션 올려놓기 딱 좋네요
#
# [현재 페이지 번호 :5]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 13
#      11 #     select함수를 사용해서, 리뷰들을 추출
#      12     review_data = soup.select('div.review_list_v2__message.js-collapsed-review-content.js-translate-text')
# ---> 13     print(review_data[pageNo].text)
#
# IndexError: list index out of range

# %%
# 여전히 공백은 존재
    # 이중 for loop을 돌려서 공백을 제거
for i in range(len(review_data)):
#     strip() 함수를 써서 문장 양 옆의 공백을 제거
    print(review_data[i].text.strip())
    print()
#    캡처나 '나는 로봇이 아닙니다' 클릭항목을 기억하는지?
# 만약 너무 많은 요청이 들어오면은, 캡처 등 사용자를 인증하는 등의 방법으로 보호
# time.sleep() 일정한 시간 간격을 주어서, 웹페이지에게 요청
    time.sleep(1)

# 적절한 딜레이 시간을 설정하는 것이 중요
print('수집완료')
# Out:
# 책뿐만 아니라 다양한 물품 두기에 좋네요 인테리에도 좋습니다
#
# 조립하는데 대략 30분걸렸네요! 생각보다 작은 감이 없지 않아 있네요! 그래도 만족합니다
#
# 손가락을 잃고 책장을 얻었다…. 뿌듯 근데 제품이 조금 까져서 왔더라구요… 괜춘괜춘합니다 ㅠㅡㅠ  하나 더 부를 거 같은데 이번에만 안까져서 오길 ㅎ ㅡㅎ
#
# 조립 무조건 둘이서 하세요 혼자 하니까 두 시간 걸렸어요.. 못할 수준은 아닌데 둘이서 하면 30분정도면 끝냈을 듯..ㅠㅠ
#
# 깔끔하고 죠습니다컬렉션 올려놓기 딱 좋네요
#
# 수집완료

# %%
# aprams : 매개변수를 사용하여 간단하게 쿼리 스트링을 추가하는 방법
# url의 끝에 ?요청 매개변수(request parameter)를 전달하기 위한 방법
for pageNo in range(1, 6):
    print(f'[{pageNo}]')
    url2 = 'https://review7.cre.ma/oneroommaking.com/products/reviews?app=0&iframe=1&iframe_id=crema-product-reviews-2&parent_url=https%3A%2F%2Foneroommaking.com%2Fproduct%2Fdetail.html%3Fproduct_no%3D1911%26cate_no%3D61%26display_group%3D1&product_code=1911&secure_device_token=V2fdea91d9154a1650500dd8e1efb74b14a4608f8a425a825f0658acf664bbd925f5a3deadcfa5bf8f9928c6d18579a1c6&widget_env=100&widget_style='
    res2 = req.get(url2, headers = header, params={'page' : pageNo})
#     params- dictionary로 정의
# key :
# page의 page로 정의
# value
# page3 = 3
# FAQ: 첫번째 페이지에는 page=1이 생략되는 건가요?
# 페이지번호는 생략되지만
# page1 = 1이 기본값으로 정의되어 있습니다.

    soup2 = bs(res2.text, 'lxml')
    review_data2 = soup.select('div.review_list_v2__message.js-collapsed-review-content.js-translate-text')
    for i in range(len(review_data2)):
        print(review_data1[i].text.strip())
        print()
    time.sleep(1)
print('수집완료')
# Out:
# [1]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 19
#      17 review_data2 = soup.select('div.review_list_v2__message.js-collapsed-review-content.js-translate-text')
#      18 for i in range(len(review_data2)):
# ---> 19     print(review_data1[i].text.strip())
#      20     print()
#      21 time.sleep(1)
#
# NameError: name 'review_data1' is not defined

# %% [markdown]
# ### 파일 생성

# %%
# 파일을 생성하고, 열고 '작성할꺼야' 하는 선언을 만들어봅시다.

f = open('review.txt', 'w', encoding = 'euc-kr')
for pageNo in range(1, 6):
    print(f'[{pageNo}]')
    url2 = 'https://review7.cre.ma/oneroommaking.com/products/reviews?app=0&iframe=1&iframe_id=crema-product-reviews-2&parent_url=https%3A%2F%2Foneroommaking.com%2Fproduct%2Fdetail.html%3Fproduct_no%3D1911%26cate_no%3D61%26display_group%3D1&product_code=1911&secure_device_token=V2fdea91d9154a1650500dd8e1efb74b14a4608f8a425a825f0658acf664bbd925f5a3deadcfa5bf8f9928c6d18579a1c6&widget_env=100&widget_style='
    res2 = req.get(url2, headers = header, params={'page' : pageNo})
#     params- dictionary로 정의
# key :
# page의 page로 정의
# value
# page3 = 3
# FAQ: 첫번째 페이지에는 page=1이 생략되는 건가요?
# 페이지번호는 생략되지만
# page1 = 1이 기본값으로 정의되어 있습니다.

    soup2 = bs(res2.text, 'lxml')
    review_data1 = soup.select('div.review_list_v2__message.js-collapsed-review-content.js-translate-text')
    for i in range(len(review_data1)):
        print(review_data1[i].text.strip())
        print()
        f.write(review_data1[i].text.strip() + '|n')
    time.sleep(1)
print('수집완료')
f.close()
# Out:
# [1]
# 책뿐만 아니라 다양한 물품 두기에 좋네요 인테리에도 좋습니다
#
# 조립하는데 대략 30분걸렸네요! 생각보다 작은 감이 없지 않아 있네요! 그래도 만족합니다
#
# 손가락을 잃고 책장을 얻었다…. 뿌듯 근데 제품이 조금 까져서 왔더라구요… 괜춘괜춘합니다 ㅠㅡㅠ  하나 더 부를 거 같은데 이번에만 안까져서 오길 ㅎ ㅡㅎ
#
# 조립 무조건 둘이서 하세요 혼자 하니까 두 시간 걸렸어요.. 못할 수준은 아닌데 둘이서 하면 30분정도면 끝냈을 듯..ㅠㅠ
#
# 깔끔하고 죠습니다컬렉션 올려놓기 딱 좋네요
#
# [2]
# 책뿐만 아니라 다양한 물품 두기에 좋네요 인테리에도 좋습니다
#
# 조립하는데 대략 30분걸렸네요! 생각보다 작은 감이 없지 않아 있네요! 그래도 만족합니다
#
# 손가락을 잃고 책장을 얻었다…. 뿌듯 근데 제품이 조금 까져서 왔더라구요… 괜춘괜춘합니다 ㅠㅡㅠ  하나 더 부를 거 같은데 이번에만 안까져서 오길 ㅎ ㅡㅎ
#
# 조립 무조건 둘이서 하세요 혼자 하니까 두 시간 걸렸어요.. 못할 수준은 아닌데 둘이서 하면 30분정도면 끝냈을 듯..ㅠㅠ
#
# 깔끔하고 죠습니다컬렉션 올려놓기 딱 좋네요
#
# [3]
# 책뿐만 아니라 다양한 물품 두기에 좋네요 인테리에도 좋습니다
#
# 조립하는데 대략 30분걸렸네요! 생각보다 작은 감이 없지 않아 있네요! 그래도 만족합니다
#
# 손가락을 잃고 책장을 얻었다…. 뿌듯 근데 제품이 조금 까져서 왔더라구요… 괜춘괜춘합니다 ㅠㅡㅠ  하나 더 부를 거 같은데 이번에만 안까져서 오길 ㅎ ㅡㅎ
#
# 조립 무조건 둘이서 하세요 혼자 하니까 두 시간 걸렸어요.. 못할 수준은 아닌데 둘이서 하면 30분정도면 끝냈을 듯..ㅠㅠ
#
# 깔끔하고 죠습니다컬렉션 올려놓기 딱 좋네요
#
# [4]
# 책뿐만 아니라 다양한 물품 두기에 좋네요 인테리에도 좋습니다
#
# 조립하는데 대략 30분걸렸네요! 생각보다 작은 감이 없지 않아 있네요! 그래도 만족합니다
#
# ...
