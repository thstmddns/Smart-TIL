# %% [markdown]
# ### 첫번째 시간입니다
# - 하잉~

# %% [markdown]
# ### 목표
# - 학생들의 수학 성적을 예측하는 회귀 모델을 만들어보자!
# - Keras를 이용해 신경망을 구성하는 방법을 익혀보자!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#print working directory : 현재 작업 경로 출력
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/SW캠프 데이터 비즈니스 과정'

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/SW캠프 데이터 비즈니스 과정
# Out:
# /content/drive/MyDrive/Colab Notebooks/SW캠프 데이터 비즈니스 과정

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/SW캠프 데이터 비즈니스 과정'

# %%
data = pd.read_csv('data/student-mat.csv', delimiter = ';')

# %%
data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0    course   mother           2          2         0       yes     no   no
# 1    course   father           1          2         0        no    yes   no
# 2     other   mother           1          2         3       yes     no  yes
# 3      home   mother           1          3         0        no    yes  yes
# 4      home   father           1          2         0        no    yes  yes
# ..      ...      ...         ...        ...       ...       ...    ...  ...
# 390  course    other           1          2         2        no    yes  yes
# 391  course   mother           2          1         0        no     no   no
# 392  course    other           1          1         3        no     no   no
# 393  course   mother           3          1         0        no     no   no
# 394  course   father           1          1         0        no     no   no
#
#     activities nursery higher internet romantic  famrel  freetime  goout  \
# 0           no     yes    yes       no       no       4         3      4
# 1           no      no    yes      yes       no       5         3      3
# 2           no     yes    yes      yes       no       4         3      2
# 3          yes     yes    yes      yes      yes       3         2      2
# 4           no     yes    yes       no       no       4         3      2
# ..         ...     ...    ...      ...      ...     ...       ...    ...
# 390         no     yes    yes       no       no       5         5      4
# 391         no      no    yes      yes       no       2         4      5
# 392         no      no    yes       no       no       5         5      3
# 393         no      no    yes      yes       no       4         4      1
# 394         no     yes    yes      yes       no       3         2      3
#
#      Dalc  Walc  health  absences  G1  G2  G3
# 0       1     1       3         6   5   6   6
# 1       1     1       3         4   5   5   6
# 2       2     3       3        10   7   8  10
# 3       1     1       5         2  15  14  15
# 4       1     2       5         4   6  10  10
# ..    ...   ...     ...       ...  ..  ..  ..
# 390     4     5       4        11   9   9   9
# 391     3     4       2         3  14  16  16
# 392     3     3       3         3  10   8   7
# 393     3     4       5         0  11  12  10
# 394     3     3       5         5   8   9   9
#
# [395 rows x 33 columns]

# %%
pd.set_option('display.max_columns', None)

# %%
data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0    course   mother           2          2         0       yes     no   no
# 1    course   father           1          2         0        no    yes   no
# 2     other   mother           1          2         3       yes     no  yes
# 3      home   mother           1          3         0        no    yes  yes
# 4      home   father           1          2         0        no    yes  yes
# ..      ...      ...         ...        ...       ...       ...    ...  ...
# 390  course    other           1          2         2        no    yes  yes
# 391  course   mother           2          1         0        no     no   no
# 392  course    other           1          1         3        no     no   no
# 393  course   mother           3          1         0        no     no   no
# 394  course   father           1          1         0        no     no   no
#
#     activities nursery higher internet romantic  famrel  freetime  goout  \
# 0           no     yes    yes       no       no       4         3      4
# 1           no      no    yes      yes       no       5         3      3
# 2           no     yes    yes      yes       no       4         3      2
# 3          yes     yes    yes      yes      yes       3         2      2
# 4           no     yes    yes       no       no       4         3      2
# ..         ...     ...    ...      ...      ...     ...       ...    ...
# 390         no     yes    yes       no       no       5         5      4
# 391         no      no    yes      yes       no       2         4      5
# 392         no      no    yes       no       no       5         5      3
# 393         no      no    yes      yes       no       4         4      1
# 394         no     yes    yes      yes       no       3         2      3
#
#      Dalc  Walc  health  absences  G1  G2  G3
# 0       1     1       3         6   5   6   6
# 1       1     1       3         4   5   5   6
# 2       2     3       3        10   7   8  10
# 3       1     1       5         2  15  14  15
# 4       1     2       5         4   6  10  10
# ..    ...   ...     ...       ...  ..  ..  ..
# 390     4     5       4        11   9   9   9
# 391     3     4       2         3  14  16  16
# 392     3     3       3         3  10   8   7
# 393     3     4       5         0  11  12  10
# 394     3     3       5         5   8   9   9
#
# [395 rows x 33 columns]

# %% [markdown]
# - 문제, 정답 분리

# %%
# 문제는 studytime, 정답은 G3
X = data['studytime']
y = data['G3']

# %%
X.shape, y.shape
# Out:
# ((395,), (395,))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=33)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (296,)
# (99,)
# (296,)
# (99,)

# %% [markdown]
# ### 신경망 모델 만들기
# - 1. 신경망 구조 설계
# - 2. 신경망 학습 및 평가 방법 설정
# - 3. 학습 및 학습과정 시각화
# - 4. 모델 평가

# %%
# 1. 신경망 구조 설계
#Sequential : 신경망의 뼈대를 구축하기 위한 함수
from tensorflow.keras import Sequential
# inputLayer: 신경망의 입력층을 생성
# Dense : 신경망 층(뉴런의 묶음)을 구성해주는 함수
from tensorflow.keras.layers import InputLayer, Dense

# %%
model = Sequential() # 신경망 뼈대 설정

# 입력층 설정
# input_shape : 입력 데이터와 특성 형태를 설정(1개의 특성을 가진)
model.add(InputLayer(input_shape=(1,)))

# 출력층 설정
# Dense : 하나의 층을 쌓아주는 함수(괄호 안의 숫자는 해당 층에 있는 뉴런의 개수)
model.add(Dense(1))

# 설계된 신경망의 정보를 요약해서 출력
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 1)                 2
#
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 2. 신경망 학습 및 평가방법 설정
# 손실함수(비용함수), 최적화함수 설정
model.compile(loss='mse',
              optimizer = 'SGD')

# %%
# 3. 학습 및 시각화
h = model.fit(X_train, y_train,
              epochs=100 # 학습 횟수 설정
              )
# Out:
# Epoch 1/100
# 10/10 [==============================] - 0s 3ms/step - loss: 94.3443
# Epoch 2/100
# 10/10 [==============================] - 0s 3ms/step - loss: 32.4787
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 26.0649
# Epoch 4/100
# 10/10 [==============================] - 0s 2ms/step - loss: 25.2411
# Epoch 5/100
# 10/10 [==============================] - 0s 2ms/step - loss: 24.8607
# Epoch 6/100
# 10/10 [==============================] - 0s 2ms/step - loss: 24.4769
# Epoch 7/100
# 10/10 [==============================] - 0s 2ms/step - loss: 24.1840
# Epoch 8/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.9586
# Epoch 9/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.6775
# Epoch 10/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.4044
# Epoch 11/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.0890
# Epoch 12/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.8695
# Epoch 13/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.6061
# Epoch 14/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.4117
# Epoch 15/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.1916
# Epoch 16/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.9765
# Epoch 17/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.8798
# Epoch 18/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.6292
# Epoch 19/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.5075
# Epoch 20/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.2637
# Epoch 21/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.0861
# Epoch 22/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.9438
# Epoch 23/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.8131
# Epoch 24/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.6987
# Epoch 25/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.6517
# Epoch 26/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.4693
# Epoch 27/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.3533
# Epoch 28/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.2402
# Epoch 29/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.1068
# Epoch 30/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.0277
# Epoch 31/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.9584
# Epoch 32/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.8138
# Epoch 33/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.7783
# Epoch 34/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.6915
# Epoch 35/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.6042
# Epoch 36/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.5017
# Epoch 37/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.4894
# Epoch 38/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.3671
# Epoch 39/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.3245
# Epoch 40/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.3984
# Epoch 41/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.3101
# Epoch 42/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.1914
# Epoch 43/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.2081
# Epoch 44/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.1801
# Epoch 45/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.0924
# Epoch 46/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.9834
# Epoch 47/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.9200
# Epoch 48/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.9364
# Epoch 49/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.8752
# Epoch 50/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.8248
# Epoch 51/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.7832
# Epoch 52/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.7316
# Epoch 53/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.7033
# Epoch 54/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.6825
# Epoch 55/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.7178
# Epoch 56/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.6600
# Epoch 57/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.5863
# Epoch 58/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.6491
# Epoch 59/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.6429
# Epoch 60/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.5805
# Epoch 61/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.5417
# Epoch 62/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.5042
# Epoch 63/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.4793
# Epoch 64/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.4727
# Epoch 65/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.4971
# Epoch 66/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.3992
# Epoch 67/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.4121
# Epoch 68/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.3936
# Epoch 69/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.3849
# Epoch 70/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.4054
# Epoch 71/100
# 10/10 [==============================] - 0s 4ms/step - loss: 18.3758
# Epoch 72/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.3458
# Epoch 73/100
# 10/10 [==============================] - 0s 4ms/step - loss: 18.3353
# Epoch 74/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.3570
# Epoch 75/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.3083
# Epoch 76/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.2950
# Epoch 77/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2529
# Epoch 78/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2986
# Epoch 79/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2769
# Epoch 80/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2354
# Epoch 81/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2834
# Epoch 82/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2687
# Epoch 83/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2531
# Epoch 84/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2626
# Epoch 85/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2529
# Epoch 86/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2552
# Epoch 87/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.1763
# Epoch 88/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.1768
# Epoch 89/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.2272
# Epoch 90/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2664
# Epoch 91/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.1614
# Epoch 92/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.1368
# Epoch 93/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.1454
# Epoch 94/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.1703
# Epoch 95/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.1517
# Epoch 96/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.1217
# Epoch 97/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.1550
# Epoch 98/100
# 10/10 [==============================] - 0s 4ms/step - loss: 18.1743
# Epoch 99/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.1558
# Epoch 100/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.1566

# %%
# 3. 학습 과정 시각화
plt.figure(figsize=(15, 5))

# history : 학습시 출력되는 값(loss,acc)들을 가져올 수 있게 해주는 명령
plt.plot(h.history['loss'], label='loss')

plt.legend()
plt.show()

# %% [markdown]
# - 초반에는 빠르게 loss값(mse)이 떨어지고 있음
# - 경사하강법 초반에는 가중치(w), 절편(b)값이 임의의 값으로 설정되어 있기 대문에 몇번만 학습시켜도 mse가 빠르게 줄어드는 것을 볼 수 있음

# %%
# 모델 평가
model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 5ms/step - loss: 29.3932
# 29.39320945739746

# %% [markdown]
# ### 입력 특성이 2개인 모델을 직접 만들어보자^_^
# - 문제 (studytime, traveltime)-X1
# - 정답(G3) - y1
# - 신경망의 최종 출력층 뉴런 개수는 1개

# %%
#직접 1~4 단계를 진행해보아요

# %%
X1 = data.loc[:, 'traveltime':'studytime']
y1 = data['G3']

# %%
X1.shape, y1.shape
# Out:
# ((395, 2), (395,))

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, random_state=33)

# %%
model1 = Sequential() # 신경망 뼈대 설정

# 입력층 설정
# input_shape : 입력 데이터와 특성 형태를 설정(1개의 특성을 가진)
model1.add(InputLayer(input_shape=(2,)))

# 출력층 설정
# Dense : 하나의 층을 쌓아주는 함수(괄호 안의 숫자는 해당 층에 있는 뉴런의 개수)
model1.add(Dense(1))

# 설계된 신경망의 정보를 요약해서 출력
model1.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_11 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 2. 신경망 학습 및 평가방법 설정
# 손실함수(비용함수), 최적화함수 설정
model1.compile(loss='mse',
              optimizer = 'SGD')

# %%
h1 = model1.fit(X1_train, y1_train,
              epochs=100 # 학습 횟수 설정
              )
# Out:
# Epoch 1/100
# 10/10 [==============================] - 0s 3ms/step - loss: 78.5979
# Epoch 2/100
# 10/10 [==============================] - 0s 3ms/step - loss: 26.9045
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 24.7904
# Epoch 4/100
# 10/10 [==============================] - 0s 2ms/step - loss: 24.4653
# Epoch 5/100
# 10/10 [==============================] - 0s 2ms/step - loss: 24.4443
# Epoch 6/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.9315
# Epoch 7/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.7366
# Epoch 8/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.5779
# Epoch 9/100
# 10/10 [==============================] - 0s 3ms/step - loss: 23.4505
# Epoch 10/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.1394
# Epoch 11/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.9457
# Epoch 12/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.7715
# Epoch 13/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.8368
# Epoch 14/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.5202
# Epoch 15/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.4581
# Epoch 16/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.2569
# Epoch 17/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.2175
# Epoch 18/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.9415
# Epoch 19/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.8768
# Epoch 20/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.8182
# Epoch 21/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.6644
# Epoch 22/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.5024
# Epoch 23/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.4241
# Epoch 24/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.4123
# Epoch 25/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.2784
# Epoch 26/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.1221
# Epoch 27/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.0699
# Epoch 28/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.9307
# Epoch 29/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.8880
# Epoch 30/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.7525
# Epoch 31/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.7258
# Epoch 32/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.6633
# Epoch 33/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.5219
# Epoch 34/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.4846
# Epoch 35/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.5299
# Epoch 36/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.3445
# Epoch 37/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.3326
# Epoch 38/100
# 10/10 [==============================] - 0s 4ms/step - loss: 20.2457
# Epoch 39/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.1852
# Epoch 40/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.1092
# Epoch 41/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.1179
# Epoch 42/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.9926
# Epoch 43/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.9208
# Epoch 44/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.9192
# Epoch 45/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.8165
# Epoch 46/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.7208
# Epoch 47/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.7166
# Epoch 48/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.5737
# Epoch 49/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.5793
# Epoch 50/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.5082
# Epoch 51/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.5049
# Epoch 52/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.4582
# Epoch 53/100
# 10/10 [==============================] - 0s 4ms/step - loss: 19.3791
# Epoch 54/100
# 10/10 [==============================] - 0s 4ms/step - loss: 19.4144
# Epoch 55/100
# 10/10 [==============================] - 0s 4ms/step - loss: 19.3005
# Epoch 56/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.2340
# Epoch 57/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.3027
# Epoch 58/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.2321
# Epoch 59/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.2150
# Epoch 60/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.0950
# Epoch 61/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.0673
# Epoch 62/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.0294
# Epoch 63/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.0037
# Epoch 64/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.0506
# Epoch 65/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.9659
# Epoch 66/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.9226
# Epoch 67/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.9075
# Epoch 68/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.8271
# Epoch 69/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.8540
# Epoch 70/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.7881
# Epoch 71/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.8152
# Epoch 72/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.7561
# Epoch 73/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.7733
# Epoch 74/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.7308
# Epoch 75/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.6681
# Epoch 76/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.6314
# Epoch 77/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.6327
# Epoch 78/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.6602
# Epoch 79/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.5754
# Epoch 80/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.5771
# Epoch 81/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.5954
# Epoch 82/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.6052
# Epoch 83/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.4883
# Epoch 84/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.5784
# Epoch 85/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.4743
# Epoch 86/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.4562
# Epoch 87/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.4653
# Epoch 88/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.4476
# Epoch 89/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.3930
# Epoch 90/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.4533
# Epoch 91/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.3539
# Epoch 92/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.3937
# Epoch 93/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.3385
# Epoch 94/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.3341
# Epoch 95/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2656
# Epoch 96/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.4463
# Epoch 97/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.3284
# Epoch 98/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.3169
# Epoch 99/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2884
# Epoch 100/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2903

# %%
plt.figure(figsize=(15, 5))

# history : 학습시 출력되는 값(loss,acc)들을 가져올 수 있게 해주는 명령
plt.plot(h1.history['loss'], label='loss')

plt.legend()
plt.show()
